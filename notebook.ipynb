# %%
from src.data import FolderStructure

FolderStructure.create()
FolderStructure.load_data()
# Out:
# Loading data...
# 	[0/500] - AAPL

# %%
from src.features import Signals

Signals.process_data()
# Out:
# Processing data...
# 	[0/500] - AAPL
